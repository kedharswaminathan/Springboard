# %% [markdown]
# # Data Preprocessing and Training Data Development
#
# ## Objective
# The goal of this project is to preprocess the Nintendo Games dataset in preparation for machine learning modeling.
#
# We will:
#
# Convert categorical variables into numeric format
# Standardize numeric features
# Split the dataset into training and testing sets
# Save a cleaned dataset for modeling

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r"C:\Users\kedha\Downloads\NintendoGames.csv")
df.head()
# Out:
#    meta_score                      title platform          date  user_score  \
# 0         NaN            Super Mario RPG   Switch  Nov 17, 2023         NaN
# 1         NaN        WarioWare: Move It!   Switch   Nov 3, 2023         NaN
# 2         NaN   Super Mario Bros. Wonder   Switch  Oct 20, 2023         NaN
# 3         NaN  Detective Pikachu Returns   Switch   Oct 6, 2023         NaN
# 4         NaN                   Fae Farm   Switch   Sep 8, 2023         NaN
#
#                                      link esrb_rating  \
# 0            /game/switch/super-mario-rpg           E
# 1         /game/switch/warioware-move-it!          RP
# 2    /game/switch/super-mario-bros-wonder           E
# 3  /game/switch/detective-pikachu-returns         NaN
# 4                   /game/switch/fae-farm        E10+
#
#                 developers                                     genres
# 0             ['Nintendo']         ['Role-Playing', 'Japanese-Style']
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   meta_score   709 non-null    float64
#  1   title        1094 non-null   str
#  2   platform     1094 non-null   str
#  3   date         1094 non-null   str
#  4   user_score   856 non-null    float64
#  5   link         1094 non-null   str
#  6   esrb_rating  972 non-null    str
#  7   developers   1091 non-null   str
#  8   genres       1094 non-null   str
# dtypes: float64(2), str(7)
# memory usage: 77.1 KB

# %%
df.describe()
# Out:
#        meta_score  user_score
# count  709.000000  856.000000
# mean    76.083216    7.671612
# std     10.610735    1.031266
# min     37.000000    3.100000
# 25%     69.000000    7.200000
# 50%     77.000000    7.900000
# 75%     83.000000    8.400000
# max     99.000000    9.600000

# %%
df.isnull().sum()
# Out:
# meta_score     385
# title            0
# platform         0
# date             0
# user_score     238
# link             0
# esrb_rating    122
# developers       3
# genres           0
# dtype: int64

# %% [markdown]
# Notes:
# Categorical columns include: title, platform, ESRB rating, developers, genres
# Numeric columns include: meta score, user score

# %%
df = df.dropna()

# %% [markdown]
# We remove missing values to ensure the dataset is clean before modeling.

# %%
df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=True)
df_encoded.head()
# Out:
#     meta_score  user_score  title_1080: Avalanche  \
# 5         87.0         9.0                  False
# 8         56.0         5.4                  False
# 9         82.0         8.4                  False
# 10        65.0         8.6                  False
# 12        96.0         8.2                  False
#
#     title_3D Classics: Kid Icarus  title_3D Classics: Kirby's Adventure  \
# 5                           False                                 False
# 8                           False                                 False
# 9                           False                                 False
# 10                          False                                 False
# 12                          False                                 False
#
#     title_3D Classics: TwinBee  title_3D Classics: Urban Champion  \
# 5                        False                              False
# 8                        False                              False
# ...

# %% [markdown]
# We separate features (inputs) from the target (what we are trying to predict).

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

X_scaled = pd.DataFrame(X_scaled, columns=X.columns)
X_scaled.head()
# Out:
#    user_score  title_100 Classic Books  title_1080: Avalanche  \
# 0         NaN                -0.030248              -0.030248
# 1         NaN                -0.030248              -0.030248
# 2         NaN                -0.030248              -0.030248
# 3         NaN                -0.030248              -0.030248
# 4         NaN                -0.030248              -0.030248
#
#    title_1080: TenEighty Snowboarding  title_3D Classics: Excitebike  \
# 0                           -0.030248                      -0.030248
# 1                           -0.030248                      -0.030248
# 2                           -0.030248                      -0.030248
# 3                           -0.030248                      -0.030248
# 4                           -0.030248                      -0.030248
#
#    title_3D Classics: Kid Icarus  title_3D Classics: Kirby's Adventure  \
# 0                      -0.030248                             -0.030248
# ...

# %% [markdown]
# Why scaling matters:
#
# Features like scores, counts, and encoded categories can have different ranges.
# Standardization ensures all features contribute equally to the model.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)

# %%
print("Training set shape:", X_train.shape)
print("Testing set shape:", X_test.shape)
# Out:
# Training set shape: (875, 3420)
# Testing set shape: (219, 3420)

# %% [markdown]
# Why split the data:
#
# We train the model on one portion of the data and evaluate it on unseen data to measure performance fairly.

# %%
processed_df = pd.concat([X_scaled, y.reset_index(drop=True)], axis=1)

processed_df.to_csv("nintendo_games_processed.csv", index=False)

# %% [markdown]
# Overview of Preprocessing Steps
#
# In this notebook, the Nintendo Games dataset was successfully prepared for machine learning modeling. The preprocessing workflow followed standard data science practices to ensure the dataset is clean, structured, and suitable for analysis.
#
# Key Steps Completed
# The dataset was loaded and explored to understand its structure, data types, and missing values.
# Categorical variables such as platform, ESRB rating, developers, and genres were identified and converted into numeric format using one-hot encoding (dummy variables).
# Missing values were handled by removing incomplete records to maintain data quality.
# Numeric features were standardized using StandardScaler to ensure all variables are on a comparable scale.
# The dataset was split into training and testing sets using an 80/20 split to allow for proper model evaluation.
# The final processed dataset was saved for future use in the modeling phase.
# Key Insights
# The dataset contains a mix of categorical and numeric variables, making encoding and scaling essential preprocessing steps.
# Features were originally on different scales, so standardization was necessary to prevent certain variables from dominating the model.
# After preprocessing, the dataset is fully numeric and ready for machine learning algorithms.
# Next Steps
#
# The next phase of the project will involve selecting and training machine learning models to predict the chosen target variable (such as meta score or user score), followed by model evaluation and performance tuning.
